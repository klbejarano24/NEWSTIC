# %%
import getpass
import pymongo

from random import randint

# %%
def insert_all_document(coleccion, fecha_noticia, actividad_economica, noticia, cobertura):
    """Return the contents of the document containing document_id"""
    fila = { "fecha_noticia" : fecha_noticia, "actividad_economica" : actividad_economica, "noticia" : noticia, "cobertura" :  cobertura}
    coleccion.insert_one(fila)

def insert_document_fecha_noticia(coleccion, fecha_noticia, noticia):
    """Return the contents of the document containing document_id"""
    fila = { "fecha_noticia" : fecha_noticia, "actividad_economica" : "", "noticia" : noticia, "cobertura" :  ""}
    coleccion.insert_one(fila)
