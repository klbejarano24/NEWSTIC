# %%
import getpass
import pymongo

from random import randint

# %%
def delete_all_document(coleccion):
    """Return the contents of the document containing document_id"""
    coleccion.delete_many({})
    print("Deleted document with {}".format(coleccion))

def delete_specific_document_id(coleccion, _id):
    """Return the contents of the document containing document_id"""
    myquery = { "_id": _id }
    coleccion.delete_one( myquery)
    print("Found a document with {}".format(_id))

def delete_specific_document_fecha(coleccion, fecha_noticia):
    """Return the contents of the document containing document_id"""
    myquery = { "fecha_noticia": fecha_noticia }
    coleccion.delete_one( myquery)
    print("Deleted document with {}".format(fecha_noticia))

def delete_specific_document_actividad(coleccion, actividad_economica):
    """Return the contents of the document containing document_id"""
    myquery = { "actividad_economica": actividad_economica }
    coleccion.delete_one( myquery)
    print("Deleted document with {}".format(actividad_economica))

def delete_specific_document_noticia(coleccion, noticia):
    """Return the contents of the document containing document_id"""
    myquery = { "noticia": noticia }
    coleccion.delete_one( myquery)
    print("Deleted document with {}".format(noticia))

def delete_specific_document_cobertura(coleccion, cobertura):
    """Return the contents of the document containing document_id"""
    myquery = { "cobertura": cobertura }
    coleccion.delete_one( myquery)
    print("Deleted document with {}".format(cobertura))
